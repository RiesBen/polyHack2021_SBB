# %%
import pandas as pd

# %%
oa_df = pd.read_pickle("ranked_trips.obj")

# %%
oa_df
# Out:
#                     lineOptions          time        length  \
# 24   {'strokeColor': '#9e324a'}  {'min': 225}  11005.000000
# 56   {'strokeColor': '#8b5831'}  {'min': 150}  20456.000000
# 55   {'strokeColor': '#9e3293'}  {'min': 311}  45325.000000
# 60   {'strokeColor': '#8b5831'}  {'min': 210}  30444.000000
# 49   {'strokeColor': '#8b5831'}  {'min': 210}  33122.000000
# ..                          ...           ...           ...
# 364  {'strokeColor': '#9e324a'}  {'min': 540}  32995.569217
# 428  {'strokeColor': '#349bb3'}   {'min': 90}  11828.775659
# 36   {'strokeColor': '#329e60'}  {'min': 120}   4744.441265
# 320  {'strokeColor': '#9e3293'}  {'min': 120}  27205.466842
# 25   {'strokeColor': '#9e324a'}  {'min': 240}  11756.000000
#
#                                              elevation  \
# 24   {'ascent': 523, 'descent': 523, 'minAltitude':...
# 56   {'ascent': 792, 'descent': 792, 'minAltitude':...
# 55   {'ascent': 1506, 'descent': 1506, 'minAltitude...
# ...
